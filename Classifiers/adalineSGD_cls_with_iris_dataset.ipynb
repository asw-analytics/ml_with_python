# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib.pyplot import figure

# %%
class AdalineSGD(object):
   '''Adaline Stochastic-Gradient-Descent (SGD) Klassificator
      Parameter
      ---------
      eta: float 
         Lernarte (zwischen 0.0 und 1.0)
      n_iter: int
         Durchläufe der Trainingsdatenmenge
      shuffle: bool (default: True)
         Durchmischt die Trainingsdaten nach jeder Epoche, falls True, um Wiederholunten zu verhindern
      random_state: int
         Initialisierung für Zufallszahlen für allfällige Gewichte
         
      Attribute
      ---------
      w_: 1d-Array
         Gewichtungen nach Anpassungen
      cost_: list
         Summe der quadrierten Werte der Straffunktion pro Epoche
      suffle: bool
         Falls True, Durchmischung nach jeder Epoche, um Wiederholungen zu verhindern
      random_state: int (Default: None)
         Anfangswert für Zufallszahlengenerator setzen
         (Durchmischen/Initialisieren der Gewichte)
   '''
   def __init__(self, eta:float =0.01 , n_iter:int =50 , shuffle:bool =True, random_state:int =None):
      self.eta          = eta
      self.n_iter       = n_iter
      self.shuffle      = shuffle
      self.random_state = random_state
      self.w_initialized = False
      
   def fit(self, X :np.array, y :np.array) -> object:
      '''Anpassen an die Trainingsdaten
      
         Parameter
         ---------
         X: {array-like}, shape = [n_samples, n_features]
            Trainingsvektoren, n_samples ist die Anzahl der Objekte
            und n_features ist die Anzahl der Merkmale
         y: {array-like}, shape = [n_samples]
            Zielwerte
         
         Rückgabewert
         ------------
         self: object

      '''
      
      print()
      print("Initialisierung der Gewichte: ")
      self._initialize_weights(X.shape[1])
      print()
      self.cost_ = []
      
      for _ in range(self.n_iter):
         if self.shuffle:
            X, y = self._shuffle(X=X, y=y)
         cost = []
         for xi, target in zip(X, y):
            cost.append(self._update_weights(xi=xi, target=target))
         avg_cost = sum(cost)/len(y)
         self.cost_.append(avg_cost)
      return self

   def partial_fit(self, X: np.array, y: np.array) -> object:
      '''Anpassung an die Trainingsdaten ohne Reinitialisierung der Gewichte'''
      if not self.w_initialized:
         self._initialize_weights(X.shape[1])
      if y.ravel().shape[0] > 1:
         for xi, target in zip(X, y):
            self._update_weights(xi=xi, target=target)
      else:
         self._update_weights(xi=X, y=y)
      return self

   def _initialize_weights(self, m):
      '''Gewichtungen mit kleinen Zufallszahlen initialisieren'''
      rgen = np.random.RandomState(self.random_state)
      self.w_ = rgen.normal(loc=0.0, scale=0.01, size=1 + m)
      self.w_initialized = True   

   def _update_weights(self, xi, target):
      '''Adaline Lernregel zur Aktualisierung der Gewichte'''
      output = self.activation(X=self.net_input(xi))
      error = (target - output)
      self.w_[1:] += self.eta * xi.dot(error)
      self.w_[0]  += self.eta * error
      print("upgedatete Gewichte: ", self.w_)
      cost = .5 * error**2
      return cost

   def _shuffle(self, X: np.array, y: np.array) -> tuple:
      '''Trainingsdaten durchmischen'''
      r = np.random.permutation(len(y))
      return X[r], y[r]

   def net_input(self, X) -> np.array:
      '''Netzeingabe berechnen'''
      return np.dot(X, self.w_[1:]) + self.w_[0]
   
   def activation(self, X: np.array) -> np.array:
      '''lineare Aktivierungsfunktion berechnen'''
      return X

   def predict(self, X) -> np.array:
      '''Klassenbezeichnung zurückgeben'''
      return np.where(self.activation(self.net_input(X)) >= 0.0, 1, -1)

# %%
s = os.path.join('https://archive.ics.uci.edu', 'ml', 'machine-learning-databases', 'iris', 'iris.data')
print('URL: ', s)
df = pd.read_csv('data/iris.data', header=None, encoding='utf-8')
df.head(10)
# Out:
# URL:  https://archive.ics.uci.edu\ml\machine-learning-databases\iris\iris.data
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa
# 5  5.4  3.9  1.7  0.4  Iris-setosa
# 6  4.6  3.4  1.4  0.3  Iris-setosa
# 7  5.0  3.4  1.5  0.2  Iris-setosa
# 8  4.4  2.9  1.4  0.2  Iris-setosa
# 9  4.9  3.1  1.5  0.1  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
# Auswahl von Setosa und Versicolor (50-50)
y = df.iloc[0:100, 4].values
y = np.where(y == 'Iris-setosa', -1, 1)   # setosa = -1 /  versicolor = 1

# %%
# Auswahl von Kelch- und Blütenblattlänge
X = df.iloc[:100, [0,2]].values    # die beiden Features oder Merkamle extrahieren

# %%
# Ausgbae der Diagramms
figure(figsize=(16, 10), dpi=80)
plt.scatter(X[:50, 0],  X[:50, 1], color='red',  marker='o', label='setosa')  
plt.suptitle("Hello SCATTER:", color="green")
plt.scatter(X[50:100, 0], X[50:100, 1], color='blue', marker='x', label='versicolor')   
plt.xlabel('Länge Kelchblatt (cm)')
plt.ylabel('Länge Blütenblatt (cm)')
plt.legend(loc='upper left')
plt.show()

# %%
# Hier standardisieren wir die Features (Merkmale) entsprechend 
X_std = np.copy(X)
X_std[:,0] = (X[:,0] - X[:,0].mean()) / X[:,0].std()
X_std[:,1] = (X[:,1] - X[:,1].mean()) / X[:,1].std()

# %%
# unseren Algorithmus erneut trainieren
ada_sgd = AdalineSGD(eta=0.01, n_iter=15, random_state=1).fit(X=X_std, y=y)
# Out:
# Initialisierung der Gewichte:
#
# upgedatete Gewichte:  [0.00592116 0.01119722 0.00590497]
# upgedatete Gewichte:  [0.01564011 0.02533843 0.01560165]
# upgedatete Gewichte:  [0.02474651 0.0442934  0.02784626]
# upgedatete Gewichte:  [0.03334931 0.06085274 0.03702621]
# upgedatete Gewichte:  [0.0238403  0.06786742 0.04667177]
# upgedatete Gewichte:  [0.01524611 0.08228344 0.05598564]
# upgedatete Gewichte:  [0.00597195 0.08621981 0.06474952]
# upgedatete Gewichte:  [-0.00229971  0.09750379  0.07256605]
# upgedatete Gewichte:  [-0.01158325  0.09853613  0.08005058]
# upgedatete Gewichte:  [-0.00360101  0.10890021  0.08856834]
# upgedatete Gewichte:  [-0.01310485  0.10400303  0.09952743]
# upgedatete Gewichte:  [-0.00624494  0.11720752  0.10827542]
# upgedatete Gewichte:  [-0.01381909  0.1263537   0.11490732]
# upgedatete Gewichte:  [-0.00496446  0.12675588  0.12435601]
# upgedatete Gewichte:  [0.00564234 0.11893138 0.12757933]
# upgedatete Gewichte:  [0.01406352 0.12195175 0.13481265]
# upgedatete Gewichte:  [0.00628746 0.12890595 0.14216086]
# upgedatete Gewichte:  [0.01523623 0.13071397 0.14674295]
# upgedatete Gewichte:  [0.00743701 0.1389104  0.15194855]
# upgedatete Gewichte:  [1.46236927e-04 1.45430609e-01 1.59344015e-01]
# upgedatete Gewichte:  [0.01445565 0.25822743 0.66324243]
# upgedatete Gewichte:  [0.01202333 0.26002172 0.66537216]
# upgedatete Gewichte:  [0.01046171 0.26166287 0.6667395 ]
# upgedatete Gewichte:  [0.00897256 0.25949613 0.66504712]
# upgedatete Gewichte:  [0.00708166 0.26089103 0.66683399]
# upgedatete Gewichte:  [0.00656178 0.26013461 0.66631531]
# upgedatete Gewichte:  [0.00424938 0.26184044 0.66834004]
# upgedatete Gewichte:  [0.01508844 0.25554223 0.66937784]
# upgedatete Gewichte:  [0.01388394 0.25435562 0.66784183]
# upgedatete Gewichte:  [0.01398927 0.25421194 0.66773499]
# upgedatete Gewichte:  [0.01647097 0.2562681  0.66969445]
# upgedatete Gewichte:  [0.01917017 0.2572362  0.67220019]
# upgedatete Gewichte:  [0.01688882 0.25820451 0.6745143 ]
# upgedatete Gewichte:  [0.01872335 0.25943714 0.67621734]
# upgedatete Gewichte:  [0.01724639 0.26075799 0.67761303]
# upgedatete Gewichte:  [0.01376719 0.26114489 0.6809008 ]
# upgedatete Gewichte:  [0.01063646 0.26296404 0.68342484]
# upgedatete Gewichte:  [0.01254344 0.2648427  0.68493052]
# upgedatete Gewichte:  [0.02133983 0.25835371 0.68882429]
# upgedatete Gewichte:  [0.02001943 0.25932775 0.69016365]
# upgedatete Gewichte:  [0.01908748 0.25811771 0.68916917]
# upgedatete Gewichte:  [0.0161004  0.25891772 0.6919919 ]
# upgedatete Gewichte:  [0.01914768 0.2533289  0.68826659]
# upgedatete Gewichte:  [0.02173901 0.25466417 0.69049239]
# upgedatete Gewichte:  [0.0188891  0.25453473 0.69358096]
# upgedatete Gewichte:  [0.01734788 0.25301639 0.69161554]
# upgedatete Gewichte:  [0.01303166 0.25349636 0.69509534]
# upgedatete Gewichte:  [0.01054579 0.25455147 0.69744443]
# upgedatete Gewichte:  [0.01626965 0.25481145 0.70077238]
# upgedatete Gewichte:  [0.01757667 0.25282374 0.69935591]
# upgedatete Gewichte:  [0.01982332 0.25292578 0.70175328]
# upgedatete Gewichte:  [0.01772616 0.25414437 0.70373504]
# upgedatete Gewichte:  [0.02187704 0.2543329  0.70701242]
# upgedatete Gewichte:  [0.02476542 0.25582124 0.70929298]
# upgedatete Gewichte:  [0.02326162 0.25481083 0.70727094]
# upgedatete Gewichte:  [0.01879864 0.25321012 0.71148836]
# upgedatete Gewichte:  [0.01483081 0.25551569 0.71413669]
# upgedatete Gewichte:  [0.01461171 0.25574596 0.71435894]
# upgedatete Gewichte:  [0.0115956  0.25560896 0.71741836]
# upgedatete Gewichte:  [0.00843525 0.25398048 0.72106264]
# upgedatete Gewichte:  [0.00715385 0.25271811 0.71951746]
# upgedatete Gewichte:  [0.01039146 0.25337225 0.72229839]
# upgedatete Gewichte:  [0.01156691 0.25360974 0.72363426]
# upgedatete Gewichte:  [0.01026514 0.25436616 0.72495473]
# upgedatete Gewichte:  [0.01252022 0.25517497 0.72704818]
# upgedatete Gewichte:  [0.01024376 0.25649775 0.72904145]
# upgedatete Gewichte:  [0.00751399 0.25295343 0.72556034]
# upgedatete Gewichte:  [0.007457   0.25301332 0.72561815]
# upgedatete Gewichte:  [0.00949034 0.24960256 0.72341453]
# upgedatete Gewichte:  [0.01289938 0.25135918 0.72586966]
# upgedatete Gewichte:  [0.01243851 0.25097733 0.72534589]
# upgedatete Gewichte:  [0.00879908 0.24625193 0.72019974]
# upgedatete Gewichte:  [0.006106   0.24908216 0.72199723]
# upgedatete Gewichte:  [0.01123305 0.24931503 0.72533392]
# upgedatete Gewichte:  [0.01399631 0.2503061  0.7277074 ]
# upgedatete Gewichte:  [0.01810981 0.2511372  0.73066986]
# upgedatete Gewichte:  [0.0237325  0.24875068 0.73471922]
# upgedatete Gewichte:  [0.02023699 0.24256972 0.73050415]
# upgedatete Gewichte:  [0.01668188 0.23962422 0.72498391]
# upgedatete Gewichte:  [0.01262645 0.24007518 0.72825346]
# upgedatete Gewichte:  [0.01203431 0.24060474 0.7288541 ]
# upgedatete Gewichte:  [0.00988193 0.23679878 0.72655732]
# upgedatete Gewichte:  [0.00789165 0.23826698 0.7283    ]
# upgedatete Gewichte:  [0.01057034 0.23880819 0.73078669]
# upgedatete Gewichte:  [0.01188325 0.23660589 0.72945493]
# upgedatete Gewichte:  [0.01003244 0.23768133 0.7312039 ]
# upgedatete Gewichte:  [0.01076971 0.23794577 0.7320418 ]
# upgedatete Gewichte:  [0.01477401 0.23812765 0.73520344]
# upgedatete Gewichte:  [0.02051778 0.24018773 0.73774595]
# upgedatete Gewichte:  [0.01781687 0.2349888  0.73486384]
# upgedatete Gewichte:  [0.01844034 0.23423593 0.73418816]
# upgedatete Gewichte:  [0.01838923 0.23430565 0.73423645]
# upgedatete Gewichte:  [0.01791967 0.2339166  0.7337028 ]
# upgedatete Gewichte:  [0.01300601 0.22368882 0.72709582]
# upgedatete Gewichte:  [0.01155109 0.22453422 0.72857163]
# upgedatete Gewichte:  [0.01098777 0.22494978 0.72918212]
# upgedatete Gewichte:  [0.01255369 0.22232309 0.72748508]
# upgedatete Gewichte:  [0.01162207 0.22125939 0.72642632]
# upgedatete Gewichte:  [0.00647122 0.21134462 0.71878565]
# upgedatete Gewichte:  [0.00343389 0.21168238 0.72165586]
# upgedatete Gewichte:  [0.00211213 0.21286444 0.72290489]
# upgedatete Gewichte:  [0.01179783 0.20420243 0.72584829]
# upgedatete Gewichte:  [0.01155615 0.20438072 0.72612698]
# upgedatete Gewichte:  [0.01159424 0.20432876 0.72608835]
# upgedatete Gewichte:  [0.00732582 0.19410699 0.72064511]
# upgedatete Gewichte:  [0.00590644 0.19582096 0.72188791]
# upgedatete Gewichte:  [0.00784468 0.19317686 0.71938392]
# upgedatete Gewichte:  [0.00287316 0.19139376 0.72339204]
# upgedatete Gewichte:  [0.00079245 0.19260279 0.72535826]
# upgedatete Gewichte:  [-0.00154351  0.19359427  0.72756569]
# upgedatete Gewichte:  [-0.00342148  0.19056767  0.72530114]
# upgedatete Gewichte:  [-0.00141819  0.1903449   0.72757782]
# upgedatete Gewichte:  [-0.00083641  0.19100916  0.72815826]
# upgedatete Gewichte:  [-0.00272429  0.19121909  0.73020423]
# upgedatete Gewichte:  [ 0.00102327 -0.02113876  0.95294656]
# upgedatete Gewichte:  [ 0.00220929 -0.02089913  0.95404757]
# upgedatete Gewichte:  [ 5.21334478e-04 -2.49413526e-02  9.51895032e-01]
# upgedatete Gewichte:  [-1.68484360e-04 -2.40003200e-02  9.52594757e-01]
# upgedatete Gewichte:  [ 0.0067613  -0.02911233  0.95470066]
# upgedatete Gewichte:  [ 0.0070078  -0.02913974  0.95443352]
# upgedatete Gewichte:  [ 0.00505352 -0.031065    0.95194136]
# upgedatete Gewichte:  [ 0.00637459 -0.03017736  0.95316775]
# upgedatete Gewichte:  [ 0.00547319 -0.02866534  0.95408209]
# upgedatete Gewichte:  [ 0.0063166  -0.02743818  0.95492356]
# upgedatete Gewichte:  [ 0.00573738 -0.0270109   0.95551109]
# upgedatete Gewichte:  [ 0.00277364 -0.03364412  0.95132036]
# upgedatete Gewichte:  [ 7.22049609e-04 -3.14880400e-02  9.53116727e-01]
# upgedatete Gewichte:  [ 0.00452625 -0.03131525  0.9555925 ]
# upgedatete Gewichte:  [ 0.00184235 -0.03311858  0.95198368]
# upgedatete Gewichte:  [ 0.00168045 -0.03312594  0.95181092]
# upgedatete Gewichte:  [ 4.65561156e-04 -3.24200096e-02  9.52958958e-01]
# upgedatete Gewichte:  [ 5.49355600e-04 -3.24818237e-02  9.52868146e-01]
# upgedatete Gewichte:  [ 8.85239602e-04 -3.24665677e-02  9.52504135e-01]
# upgedatete Gewichte:  [ 4.22145928e-04 -3.29953147e-02  9.51977842e-01]
# upgedatete Gewichte:  [ 0.00156542 -0.0324062   0.95065951]
# upgedatete Gewichte:  [ 2.43474091e-04 -3.12239779e-02  9.51908717e-01]
# upgedatete Gewichte:  [-4.31326298e-04 -3.05148096e-02  9.52593207e-01]
# upgedatete Gewichte:  [-1.95833688e-04 -3.02090477e-02  9.52844499e-01]
# upgedatete Gewichte:  [-0.0025455  -0.02994776  0.95473883]
# upgedatete Gewichte:  [-0.00357818 -0.02967119  0.95571469]
# upgedatete Gewichte:  [-0.00415798 -0.03015157  0.95505576]
# upgedatete Gewichte:  [-0.00330081 -0.02917288  0.95591097]
# upgedatete Gewichte:  [-0.00413002 -0.02947028  0.95669456]
# upgedatete Gewichte:  [ 0.00178212 -0.02734981  0.9593116 ]
# upgedatete Gewichte:  [-3.77581896e-05 -2.60073103e-02  9.60905077e-01]
# upgedatete Gewichte:  [ 0.00184299 -0.02503819  0.96252053]
# upgedatete Gewichte:  [-1.07818580e-05 -2.30900064e-02  9.64143688e-01]
# upgedatete Gewichte:  [-0.00099773 -0.0226711   0.96507634]
# upgedatete Gewichte:  [-0.00136565 -0.02239969  0.96544954]
# upgedatete Gewichte:  [-0.00125813 -0.02220955  0.96556428]
# upgedatete Gewichte:  [-0.00214587 -0.02211083  0.96640318]
# upgedatete Gewichte:  [ 8.21882468e-04 -2.33704781e-02  9.68540506e-01]
# upgedatete Gewichte:  [-4.52259333e-04 -2.56234885e-02  9.67004079e-01]
# upgedatete Gewichte:  [ 6.67212238e-04 -2.52219751e-02  9.68043314e-01]
# upgedatete Gewichte:  [-5.35736211e-04 -2.35809446e-02  9.69180074e-01]
# upgedatete Gewichte:  [-0.00139806 -0.02348505  0.96999495]
# upgedatete Gewichte:  [-0.00479486 -0.02789543  0.96519189]
# upgedatete Gewichte:  [-0.0071444  -0.03278598  0.96203267]
# upgedatete Gewichte:  [-0.00383239 -0.03107936  0.96441791]
# upgedatete Gewichte:  [-0.00414332 -0.03094739  0.9647333 ]
# upgedatete Gewichte:  [-0.00588301 -0.02966404  0.96625657]
# upgedatete Gewichte:  [-0.00585005 -0.02971933  0.96622085]
# upgedatete Gewichte:  [-0.00581873 -0.02977186  0.96618691]
# upgedatete Gewichte:  [-0.00689654 -0.02880796  0.96720542]
# upgedatete Gewichte:  [-0.00431583 -0.02747816  0.96924306]
# upgedatete Gewichte:  [-0.00212601 -0.03046546  0.96641405]
# upgedatete Gewichte:  [-0.00345815 -0.03177782  0.96480769]
# upgedatete Gewichte:  [-7.28272883e-04 -2.90884811e-02  9.66963096e-01]
# upgedatete Gewichte:  [ 0.00188523 -0.02692312  0.96902662]
# ...
# upgedatete Gewichte:  [ 0.0046117  -0.10703599  1.0507243 ]
# upgedatete Gewichte:  [ 0.00432492 -0.10659985  1.0510351 ]
# upgedatete Gewichte:  [ 6.77400740e-04 -1.04480406e-01  1.05346964e+00]
# upgedatete Gewichte:  [ 0.00240028 -0.10440215  1.05482996]
# upgedatete Gewichte:  [ 7.64369250e-04 -1.04220237e-01  1.05614885e+00]
# upgedatete Gewichte:  [-0.00282401 -0.10887936  1.05107489]
# upgedatete Gewichte:  [-1.45431262e-04 -1.08338175e-01  1.05300395e+00]
# upgedatete Gewichte:  [ 0.00305228 -0.10819293  1.05508502]
# upgedatete Gewichte:  [ 0.00191606 -0.10860046  1.05600106]
# upgedatete Gewichte:  [-6.04322706e-04 -1.14241376e-01  1.05243725e+00]
# upgedatete Gewichte:  [-0.00183909 -0.11217016  1.05368974]
# upgedatete Gewichte:  [ 0.00397408 -0.11736893  1.05545632]
# upgedatete Gewichte:  [ 0.00218554 -0.12109178  1.05305142]
# upgedatete Gewichte:  [ 0.00363104 -0.12102613  1.05148487]
# upgedatete Gewichte:  [ 0.00282778 -0.12055939  1.05224393]
# upgedatete Gewichte:  [ 5.68619868e-04 -1.22785001e-01  1.04936296e+00]
# upgedatete Gewichte:  [ 4.23764909e-04 -1.22995767e-01  1.04919834e+00]
# upgedatete Gewichte:  [-1.02056848e-03 -1.24418651e-01  1.04745669e+00]
# upgedatete Gewichte:  [ 0.00208716 -0.12281729  1.04969481]
# upgedatete Gewichte:  [ 0.00338041 -0.12093559  1.0509851 ]
# upgedatete Gewichte:  [ 0.00311525 -0.12073998  1.05125407]
# upgedatete Gewichte:  [ 0.00210049 -0.11935567  1.0522834 ]
# upgedatete Gewichte:  [ 0.00148142 -0.11831724  1.05295431]
# upgedatete Gewichte:  [ 3.58666332e-04 -1.17313152e-01  1.05401528e+00]
# upgedatete Gewichte:  [-0.00128506 -0.11507082  1.05556857]
# upgedatete Gewichte:  [-0.00213472 -0.11391174  1.05643043]
# upgedatete Gewichte:  [-0.00243542 -0.11383121  1.05671458]
# upgedatete Gewichte:  [-0.00787619 -0.11833904  1.04826636]
# upgedatete Gewichte:  [-0.00928624 -0.11884477  1.04666389]
# upgedatete Gewichte:  [-0.00984377 -0.11790956  1.04726811]
# upgedatete Gewichte:  [-0.01027683 -0.11894661  1.04671586]
# upgedatete Gewichte:  [-0.01242644 -0.11769755  1.04844891]
# upgedatete Gewichte:  [-0.01161368 -0.11766063  1.04762448]
# upgedatete Gewichte:  [-0.01353433 -0.11744705  1.04544171]
# upgedatete Gewichte:  [-0.01366084 -0.11735373  1.04557004]
# upgedatete Gewichte:  [-0.01080736 -0.11498954  1.04782304]
# upgedatete Gewichte:  [-0.00946718 -0.11471876  1.04897418]
# upgedatete Gewichte:  [-0.00541933 -0.11453491  1.05132768]
# upgedatete Gewichte:  [-0.00361401 -0.11445291  1.05275309]
# upgedatete Gewichte:  [-0.00153883 -0.11728381  1.0500722 ]
# upgedatete Gewichte:  [ 0.00333677 -0.11629873  1.05256869]
# upgedatete Gewichte:  [ 0.00330446 -0.11627996  1.05260146]
# upgedatete Gewichte:  [ 0.0025426  -0.11583727  1.0533214 ]
# upgedatete Gewichte:  [ 0.01083556 -0.12065603  1.05411542]
# upgedatete Gewichte:  [ 0.01034069 -0.12021346  1.0546174 ]
# upgedatete Gewichte:  [ 0.00903817 -0.12027262  1.0532275 ]
# upgedatete Gewichte:  [ 0.00797466 -0.12115377  1.05201884]
# upgedatete Gewichte:  [ 0.00694281 -0.12200869  1.05084618]
# upgedatete Gewichte:  [ 0.00571251 -0.12090842  1.05200878]
# upgedatete Gewichte:  [ 0.00343094 -0.12315611  1.04909924]
# upgedatete Gewichte:  [ 0.00274398 -0.12243417  1.04979606]
# upgedatete Gewichte:  [ 0.00307601 -0.12231508  1.0494823 ]
# upgedatete Gewichte:  [ 9.49029022e-04 -1.20079774e-01  1.05134468e+00]
# upgedatete Gewichte:  [-5.52669373e-04 -1.19207188e-01  1.05265956e+00]
# upgedatete Gewichte:  [-7.32302616e-04 -1.19187213e-01  1.05282931e+00]
# upgedatete Gewichte:  [-0.00128186 -0.11895396  1.05334863]
# upgedatete Gewichte:  [-0.00205377 -0.120198    1.05241782]
# upgedatete Gewichte:  [-0.001372   -0.11995347  1.05305072]
# upgedatete Gewichte:  [-0.00193543 -0.12094977  1.0523713 ]
# upgedatete Gewichte:  [-1.03470195e-03 -1.19921340e-01  1.05326997e+00]
# upgedatete Gewichte:  [-0.00469111 -0.11779672  1.05571045]
# upgedatete Gewichte:  [-0.00638751 -0.12132779  1.05342944]
# upgedatete Gewichte:  [-0.00745401 -0.12037401  1.05443725]
# upgedatete Gewichte:  [-0.00957789 -0.11913989  1.05614956]
# upgedatete Gewichte:  [-0.00375714 -0.12434544  1.05791843]
# upgedatete Gewichte:  [-0.00517901 -0.12351925  1.05916341]
# upgedatete Gewichte:  [-0.00583609 -0.12313744  1.05978434]
# upgedatete Gewichte:  [-0.00744281 -0.1209456   1.06130265]
# upgedatete Gewichte:  [-0.00825286 -0.11984054  1.06212434]
# upgedatete Gewichte:  [-0.00810679 -0.12001693  1.06196604]
# upgedatete Gewichte:  [-0.00903354 -0.12034932  1.0627132 ]
# upgedatete Gewichte:  [-0.01130967 -0.12259165  1.0598106 ]
# upgedatete Gewichte:  [-0.00934947 -0.12342364  1.0612223 ]
# upgedatete Gewichte:  [-0.01006361 -0.12457459  1.06036115]
# upgedatete Gewichte:  [-0.0121522  -0.12434233  1.05798752]
# upgedatete Gewichte:  [-0.01356349 -0.12573267  1.05628571]
# upgedatete Gewichte:  [-0.01344391 -0.12580215  1.05616441]
# upgedatete Gewichte:  [-0.00939307 -0.12561816  1.05851965]
# upgedatete Gewichte:  [-0.00943605 -0.12561338  1.05856027]
# upgedatete Gewichte:  [-0.00992419 -0.12510038  1.05905542]
# upgedatete Gewichte:  [-0.01206255 -0.12251819  1.06092776]
# upgedatete Gewichte:  [-0.01189222 -0.12261717  1.06075498]
# upgedatete Gewichte:  [-0.01041381 -0.12278157  1.05915277]
# upgedatete Gewichte:  [-0.01369188 -0.12703779  1.05451758]
# upgedatete Gewichte:  [-0.01049479 -0.12539038  1.05682006]
# upgedatete Gewichte:  [-0.00867715 -0.12530783  1.0582552 ]
# upgedatete Gewichte:  [-0.00878025 -0.12523177  1.05835978]
# upgedatete Gewichte:  [-0.00981114 -0.12430984  1.05933395]
# upgedatete Gewichte:  [-0.01081427 -0.12341273  1.06028189]
# upgedatete Gewichte:  [-0.01096025 -0.12362514  1.06011598]
# upgedatete Gewichte:  [-0.01135751 -0.12345652  1.06049138]
# upgedatete Gewichte:  [-0.01213325 -0.12288427  1.06122443]
# upgedatete Gewichte:  [-0.00937282 -0.12059718  1.06340397]
# upgedatete Gewichte:  [-0.00890729 -0.12050312  1.06383613]
# upgedatete Gewichte:  [-0.00805633 -0.11953152  1.06468514]
# upgedatete Gewichte:  [-0.00768338 -0.11968981  1.06430683]
# upgedatete Gewichte:  [-0.00621671 -0.12077175  1.06261559]
# upgedatete Gewichte:  [-0.00558592 -0.12054551  1.06320117]
# upgedatete Gewichte:  [-0.00386995 -0.12046757  1.06455604]
# upgedatete Gewichte:  [-0.00467622 -0.11936769  1.06537388]
# upgedatete Gewichte:  [-0.00353925 -0.11913798  1.06635046]
# upgedatete Gewichte:  [-0.0050458  -0.11802661  1.06766959]
# upgedatete Gewichte:  [-0.00910955 -0.1137559   1.07038194]
# upgedatete Gewichte:  [-0.01154767 -0.11615781  1.06727277]
# upgedatete Gewichte:  [-0.01147587 -0.1161658   1.06720492]
# upgedatete Gewichte:  [-0.00659088 -0.11517883  1.06970621]
# upgedatete Gewichte:  [-0.00802893 -0.11501891  1.07086558]
# upgedatete Gewichte:  [-0.00970619 -0.11562048  1.06895943]
# upgedatete Gewichte:  [-0.00866157 -0.11753635  1.06768238]
# upgedatete Gewichte:  [-0.01104135 -0.12286259  1.06431738]
# upgedatete Gewichte:  [-0.00998576 -0.12215333  1.06529731]
# upgedatete Gewichte:  [-0.01017238 -0.12198643  1.06548662]
# upgedatete Gewichte:  [-0.01138495 -0.1220415   1.0641927 ]
# upgedatete Gewichte:  [-0.01235419 -0.12284455  1.06309118]
# upgedatete Gewichte:  [-0.01197978 -0.12235842  1.06349071]
# upgedatete Gewichte:  [-0.01383329 -0.124765    1.06112705]
# upgedatete Gewichte:  [-0.01532415 -0.12366521  1.06243244]
# upgedatete Gewichte:  [-0.01397153 -0.12169714  1.06378195]
# upgedatete Gewichte:  [-0.01579633 -0.1197794   1.06537974]
# upgedatete Gewichte:  [-0.00975957 -0.12423265  1.06721427]
# upgedatete Gewichte:  [-0.0081886  -0.12342315  1.06856364]
# upgedatete Gewichte:  [-0.00721158 -0.12337877  1.06757259]
# upgedatete Gewichte:  [-0.0055137  -0.12330166  1.06573253]
# upgedatete Gewichte:  [-0.00337256 -0.12622254  1.06296642]
# upgedatete Gewichte:  [-0.00402747 -0.12584199  1.0635853 ]
# upgedatete Gewichte:  [-0.00267146 -0.12535564  1.06475004]
# upgedatete Gewichte:  [-0.00301201 -0.12483773  1.06511911]
# upgedatete Gewichte:  [-0.00646486 -0.12715772  1.06047636]
# upgedatete Gewichte:  [-0.00697951 -0.12661686  1.06099839]
# upgedatete Gewichte:  [-0.0079186  -0.12739492  1.05993115]
# upgedatete Gewichte:  [-0.00856355 -0.12702017  1.06054061]
# upgedatete Gewichte:  [-0.01052675 -0.12495698  1.06225958]
# upgedatete Gewichte:  [-0.00727791 -0.12480941  1.06437393]
# upgedatete Gewichte:  [-0.00146899 -0.12272596  1.06694527]
# upgedatete Gewichte:  [ 0.00148128 -0.12120574  1.06354325]
# upgedatete Gewichte:  [ 0.00405191 -0.12068636  1.06539457]
# upgedatete Gewichte:  [ 0.00244966 -0.1195044   1.0667975 ]
# upgedatete Gewichte:  [ 0.00517942 -0.11681518  1.06895282]
# upgedatete Gewichte:  [ 0.00475283 -0.11609961  1.06941513]
# upgedatete Gewichte:  [ 0.00431826 -0.11591516  1.06982579]
# upgedatete Gewichte:  [ 0.00480044 -0.11574222  1.06937014]
# upgedatete Gewichte:  [-8.93371221e-04 -1.20459698e-01  1.06052902e+00]
# upgedatete Gewichte:  [-2.79664186e-04 -1.20912422e-01  1.05986392e+00]
# upgedatete Gewichte:  [ 5.51477803e-04 -1.19442749e-01  1.06075082e+00]
# upgedatete Gewichte:  [ 0.00883629 -0.12425677  1.06154406]
# upgedatete Gewichte:  [ 0.00716807 -0.12407126  1.062889  ]
# upgedatete Gewichte:  [ 0.00643358 -0.12490989  1.06205426]
# upgedatete Gewichte:  [ 0.00581683 -0.12638684  1.06126777]
# upgedatete Gewichte:  [ 0.01012857 -0.12956756  1.06317638]
# upgedatete Gewichte:  [ 0.01230048 -0.1284484   1.06489124]
# upgedatete Gewichte:  [ 0.00885357 -0.13508328  1.05977817]
# upgedatete Gewichte:  [ 0.00785057 -0.13701394  1.05849911]
# upgedatete Gewichte:  [ 0.00749831 -0.13675409  1.05885642]
# upgedatete Gewichte:  [ 0.00566603 -0.13712428  1.05677408]
# upgedatete Gewichte:  [ 0.00476192 -0.13560771  1.05775391]
# upgedatete Gewichte:  [ 0.00538127 -0.13538558  1.05832886]
# upgedatete Gewichte:  [ 0.00379174 -0.13271927  1.05994122]
# upgedatete Gewichte:  [ 0.00499798 -0.13039739  1.06122839]
# upgedatete Gewichte:  [ 0.00462714 -0.13029807  1.06157883]
# upgedatete Gewichte:  [ 0.0040838  -0.13125884  1.06092363]
# upgedatete Gewichte:  [ 0.00351133 -0.13101586  1.0614646 ]
# upgedatete Gewichte:  [ 0.00126729 -0.13076632  1.05891431]
# upgedatete Gewichte:  [ 8.26358887e-04 -1.30371997e-01  1.05936157e+00]
# upgedatete Gewichte:  [ 0.00251298 -0.13029539  1.06069327]
# upgedatete Gewichte:  [ 0.00179734 -0.13144875  1.05983031]
# upgedatete Gewichte:  [-0.00141171 -0.13762577  1.05507007]
# upgedatete Gewichte:  [-0.00465952 -0.139808    1.05070302]
# upgedatete Gewichte:  [-0.00593433 -0.13866792  1.05190768]
# upgedatete Gewichte:  [-0.00695762 -0.13791305  1.05287468]
# upgedatete Gewichte:  [-0.00727901 -0.13828     1.05250943]
# upgedatete Gewichte:  [-0.00806374 -0.13782403  1.05325097]
# upgedatete Gewichte:  [-0.00748225 -0.13770654  1.05379079]
# upgedatete Gewichte:  [-0.0056722  -0.14017575  1.05145242]
# upgedatete Gewichte:  [-0.00788215 -0.13785325  1.05338745]
# upgedatete Gewichte:  [-0.00708778 -0.13756834  1.05412489]
# upgedatete Gewichte:  [ 0.00117445 -0.14236923  1.05491597]
# upgedatete Gewichte:  [-6.50729651e-04 -1.41022820e-01  1.05651409e+00]
# upgedatete Gewichte:  [-3.14703271e-04 -1.41639106e-01  1.05610330e+00]
# upgedatete Gewichte:  [-0.0010874  -0.14082705  1.05688709]
# upgedatete Gewichte:  [-0.00198486 -0.13932164  1.0578597 ]
# upgedatete Gewichte:  [-0.00204406 -0.13928724  1.05791976]
# upgedatete Gewichte:  [-0.0021814  -0.13927196  1.05804954]
# upgedatete Gewichte:  [-0.00223643 -0.13923999  1.05810535]
# upgedatete Gewichte:  [-0.0038995  -0.14139932  1.05598454]
# upgedatete Gewichte:  [-0.00507796 -0.1397917   1.05717992]
# upgedatete Gewichte:  [-0.00489692 -0.13986854  1.05699627]
# upgedatete Gewichte:  [-0.00173952 -0.13824158  1.05927017]
# upgedatete Gewichte:  [-0.00234474 -0.13732115  1.05992608]
# upgedatete Gewichte:  [-0.00150746 -0.13728313  1.05907678]
# upgedatete Gewichte:  [ 0.0016775  -0.13713846  1.06114955]
# upgedatete Gewichte:  [ 0.00159645 -0.13725639  1.06105744]
# upgedatete Gewichte:  [ 6.59076445e-04 -1.38033029e-01  1.05999215e+00]
# upgedatete Gewichte:  [ 0.00494213 -0.14119258  1.06188806]
# upgedatete Gewichte:  [ 0.00432803 -0.14093193  1.06246837]
# upgedatete Gewichte:  [-1.04888701e-04 -1.36273242e-01  1.06542713e+00]
# upgedatete Gewichte:  [-0.00242057 -0.13347694  1.06745473]
# upgedatete Gewichte:  [-6.50510075e-04 -1.34228229e-01  1.06872949e+00]
# upgedatete Gewichte:  [-8.38743838e-05 -1.34024997e-01  1.06925552e+00]
# upgedatete Gewichte:  [-1.13495195e-04 -1.33989228e-01  1.06928762e+00]
# upgedatete Gewichte:  [-0.0015135  -0.13164084  1.07070772]
# upgedatete Gewichte:  [-0.00288821 -0.13084205  1.07191141]
# upgedatete Gewichte:  [ 0.00191645 -0.1298713   1.07437157]
# upgedatete Gewichte:  [ 0.00251566 -0.12965639  1.07380533]
# upgedatete Gewichte:  [ 0.00325745 -0.12880944  1.07454541]
# upgedatete Gewichte:  [ 0.00303411 -0.12874963  1.07475646]
# upgedatete Gewichte:  [ 5.66477303e-04 -1.31180613e-01  1.07160966e+00]
# upgedatete Gewichte:  [ 5.21699897e-05 -1.30640112e-01  1.07213135e+00]
# upgedatete Gewichte:  [ 3.07268046e-04 -1.30308894e-01  1.07240356e+00]
# upgedatete Gewichte:  [-0.00162008 -0.1306983   1.07021318]
# upgedatete Gewichte:  [-0.00381149 -0.13560293  1.06711455]
# upgedatete Gewichte:  [-0.00479885 -0.13425599  1.06811609]
# upgedatete Gewichte:  [ 8.02557900e-04 -1.39265377e-01  1.06981831e+00]
# upgedatete Gewichte:  [-0.00130176 -0.13705388  1.07166084]
# upgedatete Gewichte:  [-0.00231681 -0.13900773  1.07036642]
# upgedatete Gewichte:  [-0.00261445 -0.13972049  1.06998686]
# upgedatete Gewichte:  [-0.00114778 -0.13988359  1.06839738]
# upgedatete Gewichte:  [-0.00281336 -0.13865491  1.06985576]
# upgedatete Gewichte:  [-0.00456682 -0.13626289  1.07151274]
# upgedatete Gewichte:  [-0.00163903 -0.13337857  1.07382441]
# upgedatete Gewichte:  [-7.22831439e-04 -1.31758499e-01  1.07480208e+00]
# upgedatete Gewichte:  [ 3.18649102e-04 -1.31548076e-01  1.07569665e+00]
# upgedatete Gewichte:  [-0.00135991 -0.13320171  1.07367256]
# upgedatete Gewichte:  [-0.00194483 -0.13222056  1.07430646]
# upgedatete Gewichte:  [-6.78850914e-04 -1.31766499e-01  1.07539386e+00]
# upgedatete Gewichte:  [-0.00152948 -0.13207159  1.07607965]
# upgedatete Gewichte:  [-0.0036061  -0.13086494  1.07775385]
# upgedatete Gewichte:  [-0.00414591 -0.13055127  1.07826396]
# upgedatete Gewichte:  [-0.00588554 -0.1341723   1.07592483]
# upgedatete Gewichte:  [-0.00730162 -0.13401483  1.0770665 ]
# upgedatete Gewichte:  [-0.00567186 -0.13394081  1.0783533 ]
# upgedatete Gewichte:  [-0.00716118 -0.13284215  1.07965735]
# upgedatete Gewichte:  [-0.00592852 -0.13104862  1.08088718]
# upgedatete Gewichte:  [-0.00437201 -0.13219684  1.07909233]
# upgedatete Gewichte:  [-0.00435762 -0.13220746  1.07907773]
# upgedatete Gewichte:  [-0.00677237 -0.13458635  1.07599835]
# upgedatete Gewichte:  [-0.01030492 -0.13253371  1.07835616]
# upgedatete Gewichte:  [-0.0111969  -0.131736    1.07919906]
# upgedatete Gewichte:  [-0.01103323 -0.1317542   1.0790444 ]
# upgedatete Gewichte:  [-0.00522679 -0.12967164  1.08161465]
# upgedatete Gewichte:  [-0.01089504 -0.13436795  1.0728132 ]
# upgedatete Gewichte:  [-0.0050375  -0.13868899  1.07459326]
# upgedatete Gewichte:  [-0.00510997 -0.13863552  1.07466678]
# upgedatete Gewichte:  [-0.00443497 -0.13913347  1.07393524]
# upgedatete Gewichte:  [-0.00289819 -0.13834159  1.07525525]
# upgedatete Gewichte:  [-0.00435418 -0.13817969  1.07642909]
# upgedatete Gewichte:  [-0.00537438 -0.13726732  1.07739315]
# upgedatete Gewichte:  [-0.00417515 -0.13495896  1.07867283]
# upgedatete Gewichte:  [-0.00558251 -0.13502288  1.07717105]
# upgedatete Gewichte:  [-0.00461912 -0.13437557  1.07806539]
# upgedatete Gewichte:  [-0.00571149 -0.13528063  1.07682394]
# upgedatete Gewichte:  [-0.00254019 -0.13364651  1.07316705]
# upgedatete Gewichte:  [ 2.64815647e-05 -1.33127935e-01  1.07501552e+00]
# upgedatete Gewichte:  [ 0.00222428 -0.13199544  1.07675082]
# upgedatete Gewichte:  [ 0.00600157 -0.13182388  1.078947  ]
# upgedatete Gewichte:  [ 0.00769442 -0.13174699  1.07711239]
# upgedatete Gewichte:  [ 0.01020455 -0.12966727  1.0790943 ]
# upgedatete Gewichte:  [ 0.00954626 -0.12928476  1.07971637]
# upgedatete Gewichte:  [ 0.00764383 -0.12996709  1.07755432]
# upgedatete Gewichte:  [ 0.00687182 -0.13133219  1.07662339]
# upgedatete Gewichte:  [ 0.00328488 -0.13598945  1.07155146]

# %%
def plot_decision_regions(X, y, classifier, resolution=.01):

    # setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('hotpink', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - .3, X[:, 0].max() + .3
    x2_min, x2_max = X[:, 1].min() - .3, X[:, 1].max() + .3

    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution), np.arange(x2_min, x2_max, resolution))
    print("Shape xx1: ", xx1.shape, "  /  Type: ", type(xx1))
    print("Shape xx2: ", xx2.shape, "  /  Type: ", type(xx2))
    print("Flatten, für die Verwendung in PREDICT Classifier: ", xx1.ravel().shape)
    print("np.array Transpose: ", np.array([xx1.ravel()]).T)
    
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    print("Z-shape: ", Z.shape, "  /  Type: ", type(Z))
    Z = Z.reshape(xx1.shape)
    print("Re-Shaped: ", Z.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    # plot class examples
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], 
                    y=X[y == cl, 1],
                    alpha=0.8, 
                    c=colors[idx],
                    marker=markers[idx], 
                    label=cl, 
                    edgecolor='black')

# %%
figure(figsize=(10, 7), dpi=100)
plot_decision_regions(X_std, y, classifier=ada_sgd)
plt.title("Adaline - Stochastisches Gradientenabstiegsverfahren")
plt.xlabel('Länge Kelchblatt [standardisiert]')
plt.ylabel('Länge Blütenblatt [standardisiert]')
plt.legend(loc='upper left')
plt.show()   

figure(figsize=(10, 7), dpi=100)
plt.plot(range(1, len(ada_sgd.cost_) + 1), ada_sgd.cost_, marker='o')
plt.xlabel("Epochen")
plt.ylabel("Durchschnittswert der Straffunktion")
plt.show()
# Out:
# Shape xx1:  (345, 483)   /  Type:  <class 'numpy.ndarray'>
# Shape xx2:  (345, 483)   /  Type:  <class 'numpy.ndarray'>
# Flatten, für die Verwendung in PREDICT Classifier:  (166635,)
# np.array Transpose:  [[-2.1340382]
#  [-2.1240382]
#  [-2.1140382]
#  ...
#  [ 2.6659618]
#  [ 2.6759618]
#  [ 2.6859618]]
# Z-shape:  (166635,)   /  Type:  <class 'numpy.ndarray'>
# Re-Shaped:  (345, 483)
